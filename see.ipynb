# %%
import matplotlib.pyplot as plt
import torch

# %%
data = torch.load('/home/xiangcen/ipmi2088/saved_value_fix_seg.pt')
plt.plot(data[:, 0], label='train')
plt.plot(data[:, 1], label='test')
plt.legend()

# %%
data = torch.load('/home/xiangcen/ipmi2088/saved_value_fix_seg_sigmoid.pt')
plt.plot(data[:, 0], label='train')
plt.plot(data[:, 1], label='test')
plt.legend()

# %%
data = torch.load('/home/xiangcen/ipmi2088/saved_value_fix_seg_jicv2.pt')
plt.plot(data[:, 0], label='train')
plt.plot(data[:, 1], label='test')
plt.legend()

# %%
data = torch.load('/home/xiangcen/ipmi2088/saved_value_last_exp.pt')
plt.plot(data[:, 0], label='train')
plt.plot(data[:, 1], label='test')
plt.legend()
