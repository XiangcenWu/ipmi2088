# %%
import torch
import matplotlib.pyplot as plt



device = 'cpu'

# %%
data = torch.load("/home/xiangcen/ipmi2088/before_meeting/segloss_fix_v2.pt").to(device)
plt.plot(data[:, 0], label='train')
plt.plot(1 - data[:, 1], label="test")
plt.legend()
