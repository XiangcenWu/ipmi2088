# %%
import re
from pathlib import Path
from PIL import Image
from sklearn.model_selection import train_test_split
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.transforms as T

import monai
from monai.networks.nets.unet import UNet
from monai.losses import DiceLoss

from model import SelectionNet
from train import *

from scipy.stats import rankdata

root_dir = "./data/malignant"
regex = re.compile(r"\d+")

def path_list_ranking(path_list):
    return sorted(path_list, key=lambda i: int(regex.findall(i)[0]))

def data_path_list(root_dir):
    path = Path(root_dir)
    all_paths = [str(image_path) for image_path in path.glob("*.png")]
    imgs_list = [img_path for img_path in all_paths if "_mask" not in img_path]
    labels_list = [label_path for label_path in all_paths if "_mask" in label_path]
    return path_list_ranking(imgs_list), path_list_ranking(labels_list)


imgs_list, labels_list = data_path_list(root_dir)


meta_train_list, meta_val_list, meta_train_label_list, meta_val_label_list = train_test_split(imgs_list, labels_list, test_size=120, train_size=90, random_state=25)
meta_val_list, holdout_list, meta_val_label_list, holdout_label_list = train_test_split(meta_val_list, meta_val_label_list, test_size=30, train_size=90, random_state=25)

print(len(holdout_list))

class Dataset(torch.utils.data.Dataset):
    
    def __init__(self, images_list :list, 
                 labels_list :list, 
                 img_transform :T=None ,
                 label_transform :T=None):
        super().__init__()
        
        assert len(images_list) == len(labels_list) # images labels have numbers doesn't match
        self.images_list = images_list
        self.labels_list = labels_list
        self.img_transform = img_transform
        self.label_transform = label_transform
        
        
    def __len__(self):
        return len(self.images_list)
    
    def __getitem__(self, index):
        image = Image.open(self.images_list[index])
        label = Image.open(self.labels_list[index])
        
        return self.img_transform(image), self.label_transform(label)

    
    
basic_transform = T.Compose([
    T.Resize([324,324]),
#     T.Grayscale(1),
#     T.GaussianBlur(kernel_size=(3, 7), sigma=(0.1, 5)),
    T.ToTensor(),
#     T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

basic_label_transform = T.Compose([
    T.Resize([324,324]),
    T.ToTensor()
])

Holdout_test_dataset = Dataset(holdout_list, holdout_label_list, basic_transform, basic_label_transform)

test_loader = DataLoader(Holdout_test_dataset, batch_size=10, shuffle=True, drop_last=True)


device = 'cuda:0'
nick_name = 'justmmd_true'
Seg_model = UNet(
    spatial_dims=2,
    in_channels=3,
    out_channels=1,
    channels=(64, 128, 256, 512, 1024),
    strides=(2, 2, 1, 1),
    num_res_units=3,
    dropout = 0.2
)
Seg_model.load_state_dict(torch.load("/home/xiangcen/ipmi2088/seg_fix.pt", map_location=device))
Seg_model.to(device)

Sel_model = SelectionNet(
    DS_dim_list=[3, 64, 256, 512, 1024, 2048], 
    num_resblock=2, 
    transformer_input_dim=2048, 
    num_head=8,
    dropout=0.,
    num_transformer=6
)

Sel_model.load_state_dict(torch.load("/home/xiangcen/ipmi2088/sel_fix_seg_jic.pt", map_location=device))
Sel_model.to(device)


def metric_sel_net(
        seg_model, 
        sel_model, 
        holdout_loader,
        device='cpu'
    ):
    # remember the loader should drop the last batch to prevent differenct sequence number in the last batch
    seg_model.eval()
    seg_model.to(device)
    sel_model.eval()
    sel_model.to(device)
    step = 0.
    performance_all = 0.
    selection_list = []
    performance_list = []
    for img, label in holdout_loader:
        img, label = img.to(device), label.to(device)
        # forward pass and calculate the selection
        
        
        with torch.no_grad():
            selection_output = sel_model(img)
            # calculate the performance of the sequence
            o = seg_model(img)
            performance = dice_metric(o, label, sigmoid=True, mean=False)

            # print(performance, selection_output)

            selection_list.append(selection_output)
            performance_list.append(performance)

        
        step += 1
        performance_all += performance.mean().item()
        


    return performance_all/step, selection_list, performance_list
# _, sel, per = metric_sel_net(Seg_model, Sel_model, test_loader)
# _, sel, per
# Out:
# 30

# %%
list = []
for j in range(10):
    _, sel, per = metric_sel_net(Seg_model, Sel_model, test_loader, device=device)
    for i in range(3):
        batch_index = sel[i]
        performance = per[i]
        i_max = torch.argmax(batch_index).item()
        i_min = torch.argmin(batch_index).item()

        mean_performance = performance.mean()
        selected_performance = (performance[i_max] + performance[i_min]) / 2
        random_performance = performance[torch.randint(0, 10, (2, ))].mean()


        selected_difference, random_difference = (torch.abs(mean_performance - selected_performance), torch.abs(mean_performance - random_performance))

        list.append(torch.tensor([selected_difference, random_difference]))
result = torch.stack(list)

# %%
torch.mean(result, dim=0), torch.std(result, dim=0)
# Out:
# (tensor([0.0532, 0.1026]), tensor([0.0311, 0.0789]))

# %%
torch.mean(result, dim=0), torch.std(result, dim=0)
# Out:
# (tensor([0.0532, 0.1026]), tensor([0.0311, 0.0789]))

# %%
meta_val_list, meta_val_label_list
# Out:
# (['data/malignant/malignant (94).png',
#   'data/malignant/malignant (8).png',
#   'data/malignant/malignant (60).png',
#   'data/malignant/malignant (165).png',
#   'data/malignant/malignant (182).png',
#   'data/malignant/malignant (29).png',
#   'data/malignant/malignant (153).png',
#   'data/malignant/malignant (9).png',
#   'data/malignant/malignant (106).png',
#   'data/malignant/malignant (113).png',
#   'data/malignant/malignant (87).png',
#   'data/malignant/malignant (35).png',
#   'data/malignant/malignant (21).png',
#   'data/malignant/malignant (95).png',
#   'data/malignant/malignant (88).png',
#   'data/malignant/malignant (124).png',
#   'data/malignant/malignant (73).png',
#   'data/malignant/malignant (169).png',
#   'data/malignant/malignant (162).png',
#   'data/malignant/malignant (32).png',
#   'data/malignant/malignant (44).png',
#   'data/malignant/malignant (71).png',
#   'data/malignant/malignant (163).png',
#   'data/malignant/malignant (76).png',
#   'data/malignant/malignant (129).png',
#   'data/malignant/malignant (11).png',
#   'data/malignant/malignant (53).png',
#   'data/malignant/malignant (38).png',
#   'data/malignant/malignant (34).png',
#   'data/malignant/malignant (75).png',
#   'data/malignant/malignant (127).png',
#   'data/malignant/malignant (42).png',
#   'data/malignant/malignant (178).png',
#   'data/malignant/malignant (123).png',
#   'data/malignant/malignant (81).png',
#   'data/malignant/malignant (7).png',
#   'data/malignant/malignant (136).png',
#   'data/malignant/malignant (92).png',
#   'data/malignant/malignant (140).png',
#   'data/malignant/malignant (185).png',
#   'data/malignant/malignant (134).png',
#   'data/malignant/malignant (103).png',
#   'data/malignant/malignant (171).png',
#   'data/malignant/malignant (22).png',
#   'data/malignant/malignant (204).png',
#   'data/malignant/malignant (120).png',
#   'data/malignant/malignant (176).png',
#   'data/malignant/malignant (59).png',
#   'data/malignant/malignant (115).png',
#   'data/malignant/malignant (196).png',
#   'data/malignant/malignant (31).png',
#   'data/malignant/malignant (189).png',
#   'data/malignant/malignant (97).png',
#   'data/malignant/malignant (43).png',
#   'data/malignant/malignant (118).png',
#   'data/malignant/malignant (33).png',
#   'data/malignant/malignant (170).png',
#   'data/malignant/malignant (167).png',
#   'data/malignant/malignant (192).png',
#   'data/malignant/malignant (1).png',
#   'data/malignant/malignant (155).png',
#   'data/malignant/malignant (200).png',
#   'data/malignant/malignant (36).png',
#   'data/malignant/malignant (69).png',
#   'data/malignant/malignant (112).png',
#   'data/malignant/malignant (190).png',
#   'data/malignant/malignant (26).png',
#   'data/malignant/malignant (197).png',
#   'data/malignant/malignant (79).png',
#   'data/malignant/malignant (55).png',
#   'data/malignant/malignant (5).png',
#   'data/malignant/malignant (142).png',
#   'data/malignant/malignant (177).png',
#   'data/malignant/malignant (41).png',
#   'data/malignant/malignant (114).png',
#   'data/malignant/malignant (78).png',
#   'data/malignant/malignant (208).png',
#   'data/malignant/malignant (175).png',
#   'data/malignant/malignant (66).png',
#   'data/malignant/malignant (183).png',
#   'data/malignant/malignant (50).png',
#   'data/malignant/malignant (126).png',
#   'data/malignant/malignant (172).png',
#   'data/malignant/malignant (108).png',
#   'data/malignant/malignant (201).png',
#   'data/malignant/malignant (101).png',
#   'data/malignant/malignant (122).png',
#   'data/malignant/malignant (150).png',
#   'data/malignant/malignant (191).png',
#   'data/malignant/malignant (206).png'],
#  ['data/malignant/malignant (94)_mask.png',
#   'data/malignant/malignant (8)_mask.png',
#   'data/malignant/malignant (60)_mask.png',
#   'data/malignant/malignant (165)_mask.png',
#   'data/malignant/malignant (182)_mask.png',
#   'data/malignant/malignant (29)_mask.png',
#   'data/malignant/malignant (153)_mask.png',
#   'data/malignant/malignant (9)_mask.png',
#   'data/malignant/malignant (106)_mask.png',
#   'data/malignant/malignant (113)_mask.png',
#   'data/malignant/malignant (87)_mask.png',
#   'data/malignant/malignant (35)_mask.png',
#   'data/malignant/malignant (21)_mask.png',
#   'data/malignant/malignant (95)_mask.png',
#   'data/malignant/malignant (88)_mask.png',
#   'data/malignant/malignant (124)_mask.png',
#   'data/malignant/malignant (73)_mask.png',
#   'data/malignant/malignant (169)_mask.png',
#   'data/malignant/malignant (162)_mask.png',
#   'data/malignant/malignant (32)_mask.png',
#   'data/malignant/malignant (44)_mask.png',
#   'data/malignant/malignant (71)_mask.png',
#   'data/malignant/malignant (163)_mask.png',
#   'data/malignant/malignant (76)_mask.png',
#   'data/malignant/malignant (129)_mask.png',
#   'data/malignant/malignant (11)_mask.png',
#   'data/malignant/malignant (53)_mask.png',
#   'data/malignant/malignant (38)_mask.png',
#   'data/malignant/malignant (34)_mask.png',
#   'data/malignant/malignant (75)_mask.png',
#   'data/malignant/malignant (127)_mask.png',
#   'data/malignant/malignant (42)_mask.png',
#   'data/malignant/malignant (178)_mask.png',
#   'data/malignant/malignant (123)_mask.png',
#   'data/malignant/malignant (81)_mask.png',
#   'data/malignant/malignant (7)_mask.png',
#   'data/malignant/malignant (136)_mask.png',
#   'data/malignant/malignant (92)_mask.png',
#   'data/malignant/malignant (140)_mask.png',
#   'data/malignant/malignant (185)_mask.png',
#   'data/malignant/malignant (134)_mask.png',
#   'data/malignant/malignant (103)_mask.png',
#   'data/malignant/malignant (171)_mask.png',
#   'data/malignant/malignant (22)_mask.png',
#   'data/malignant/malignant (204)_mask.png',
#   'data/malignant/malignant (120)_mask.png',
#   'data/malignant/malignant (176)_mask.png',
#   'data/malignant/malignant (59)_mask.png',
#   'data/malignant/malignant (115)_mask.png',
#   'data/malignant/malignant (196)_mask.png',
#   'data/malignant/malignant (31)_mask.png',
#   'data/malignant/malignant (189)_mask.png',
#   'data/malignant/malignant (97)_mask.png',
#   'data/malignant/malignant (43)_mask.png',
#   'data/malignant/malignant (118)_mask.png',
#   'data/malignant/malignant (33)_mask.png',
#   'data/malignant/malignant (170)_mask.png',
#   'data/malignant/malignant (167)_mask.png',
#   'data/malignant/malignant (192)_mask.png',
#   'data/malignant/malignant (1)_mask.png',
#   'data/malignant/malignant (155)_mask.png',
#   'data/malignant/malignant (200)_mask.png',
#   'data/malignant/malignant (36)_mask.png',
#   'data/malignant/malignant (69)_mask.png',
#   'data/malignant/malignant (112)_mask.png',
#   'data/malignant/malignant (190)_mask.png',
#   'data/malignant/malignant (26)_mask.png',
#   'data/malignant/malignant (197)_mask.png',
#   'data/malignant/malignant (79)_mask.png',
#   'data/malignant/malignant (55)_mask.png',
#   'data/malignant/malignant (5)_mask.png',
#   'data/malignant/malignant (142)_mask.png',
#   'data/malignant/malignant (177)_mask.png',
#   'data/malignant/malignant (41)_mask.png',
#   'data/malignant/malignant (114)_mask.png',
#   'data/malignant/malignant (78)_mask.png',
#   'data/malignant/malignant (208)_mask.png',
#   'data/malignant/malignant (175)_mask.png',
#   'data/malignant/malignant (66)_mask.png',
#   'data/malignant/malignant (183)_mask.png',
#   'data/malignant/malignant (50)_mask.png',
#   'data/malignant/malignant (126)_mask.png',
#   'data/malignant/malignant (172)_mask.png',
#   'data/malignant/malignant (108)_mask.png',
#   'data/malignant/malignant (201)_mask.png',
#   'data/malignant/malignant (101)_mask.png',
#   'data/malignant/malignant (122)_mask.png',
#   'data/malignant/malignant (150)_mask.png',
#   'data/malignant/malignant (191)_mask.png',
#   'data/malignant/malignant (206)_mask.png'])
